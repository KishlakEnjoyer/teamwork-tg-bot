# %%
pip install openai-whisper
# Out:
# ...
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ------------- -------------------------- 262.1/803.2 kB ? eta -:--:--
#      ---------------------------------------- 803.2/803.2 kB 6.4 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------- ----------------- 1.6/2.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 8.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/39.2 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/39.2 MB 11.8 MB/s eta 0:00:04
# ...

# %%
import whisper

model = whisper.load_model("tiny")

# %%
result = model.transcribe("audio_2026-03-06_01-02-28.ogg")

print(result["text"])
# Out:
# c:\Users\erikf\repositories\teamwork-tg-bot\venv\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Привет Владик!
